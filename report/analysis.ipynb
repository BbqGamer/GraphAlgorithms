# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14,
                     'figure.dpi': 100,
                    })

# %%
df = pd.read_csv('../data/csv/xlookup.csv')
df = df[df['time'] < 0.2]

# %%
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

R = ["Vertex Matrix", "Incident Matrix", "Incidence List", "Edge List"]
for r in R: 
    X = df[df['repr'] == r].n
    Y = df[df['repr'] == r].time
    plt.plot(X, Y, label=r)

plt.legend(loc="best")
plt.xlabel("Number of vertices")
plt.ylabel("Time (ms)")

plt.show()

# %%
df = pd.read_csv('../data/csv/topsortFINAL.csv')
plt.plot(df.n, df.time, label='topsort')
plt.title("Time taken to perform topological sort on DAG")
plt.xlabel("Number of vertices")
plt.ylabel("Time (ms)")
# Out:
# Text(0, 0.5, 'Time (ms)')
